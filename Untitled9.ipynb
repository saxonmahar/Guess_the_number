# %% [markdown]
# <a href="https://colab.research.google.com/github/saxonmahar/Guess_the_number/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3820d19b-ff79-4f2a-9937-13e5a5eef1fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3820d19b-ff79-4f2a-9937-13e5a5eef1fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('mt_everest.csv')

# %%
df=pd.read_csv('mt_everest.csv')

# %%
df.columns
# Out:
# Index(['_id', 'NAME', 'COUNTRY', 'DAY', 'MONTH', 'YEAR', 'ROUTE',
#        'NAME OF THE TEAM', 'LEADER'],
#       dtype='object')

# %%
df['NAME'].value_counts()
# Out:
# NAME
# MR. PASANG SHERPA         15
# MR. LAKPA NURU SHERPA     15
# MR. JANGBU SHERPA         15
# MR. PASANG DAWA SHERPA    12
# DORJEE SHERPA             12
#                           ..
# NORBU BHOTE                1
# JAMES DURIE KERR           1
# DOUGLAS P. BEAL            1
# MS. SAMANTHA LARSON        1
# GORDON M. CLARK            1
# Name: count, Length: 4106, dtype: int64

# %%
plt.bar(df['NAME'].value_counts().index[:10],df['NAME'].value_counts().values[:10])
plt.xticks(rotation=90)
plt.xlabel('no of climber')
plt.ylabel('no of times')
plt.title('bar plot')
plt.show()

# %%
plt.bar(df['COUNTRY'].value_counts().index[:10],df['COUNTRY'].value_counts().values[:10])
plt.xticks(rotation=90)
plt.xlabel('no of climber')
plt.ylabel('no of times')
plt.title('bar plot')
plt.show()

# %%
x1=[1,2,3,4,5]
y1=[2,3,5,7,11]
x2=[1,2,3,4,5]
y2=[10,20,30,40,50]
plt.plot(x1,y1,label='line1')
plt.plot(x2,y2,label='line2')
plt.xlim(0,10)
plt.ylim(0,60)
plt.legend()
plt.show()

# %%
x=[1,2,3,4,5]
y=[2,3,5,7,11]
plt.plot(x,y,'red',marker='*',linestyle=':')
plt.text(2,6,'this is important point',fontsize=12)
plt.xlabel('x-axis')
plt.ylabel('y_axis')
plt.title('temp_plot')
plt.show()
plt.savefig('plot.png')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset from a URL

df=pd.read_csv('mt_everest.csv')
# Display the first 5 rows
df.head()
# Out:
#    _id            NAME      COUNTRY  DAY  MONTH  YEAR     ROUTE  \
# 0    1  TENZING NORGAY        NEPAL   29      5  1953  SOUTHCOL
# 1    2  EDMUND HILLARY  NEW ZEALAND   29      5  1953  SOUTHCOL
# 2    3   ERNST SCHMIED  SWITZERLAND   23      5  1956  SOUTHCOL
# 3    4   JUERGE MARMET  SWITZERLAND   23      5  1956  SOUTHCOL
# 4    5     ADOLF REIST  SWITZERLAND   24      5  1956  SOUTHCOL
#
#          NAME OF THE TEAM          LEADER
# 0      BRITISH EXPEDITION  Lord John Hunt
# 1      BRITISH EXPEDITION               "
# 2  SWITZERLAND EXPEDITION    Alber Eggler
# 3  SWITZERLAND EXPEDITION               "
# 4  SWITZERLAND EXPEDITION               "

# %%
df.tail()
# Out:
#        _id                     NAME COUNTRY  DAY  MONTH  YEAR ROUTE  \
# 5296  5297    MR. PEMBA RITA SHERPA   NEPAL   27      5  2017   NaN
# 5297  5298       MR. PASANG GYALZEN   NEPAL   27      5  2017   NaN
# 5298  5299  MR. MINGMA DORJI SHERPA   NEPAL   16      5  2017   NaN
# 5299  5300    MR. DAWA SANGE SHERPA   NEPAL   21      5  2017   NaN
# 5300  5301         MR. PASANG BHOTE   NEPAL   21      5  2017   NaN
#
#      NAME OF THE TEAM LEADER
# 5296                "      "
# 5297              NaN    NaN
# 5298                "      "
# 5299                "      "
# 5300                "      "

# %%
import pandas as pd

df = pd.read_csv('mt_everest.csv')
print(df.columns)
df.head()
# Out:
# Index(['_id', 'NAME', 'COUNTRY', 'DAY', 'MONTH', 'YEAR', 'ROUTE',
#        'NAME OF THE TEAM', 'LEADER'],
#       dtype='object')
#    _id            NAME      COUNTRY  DAY  MONTH  YEAR     ROUTE  \
# 0    1  TENZING NORGAY        NEPAL   29      5  1953  SOUTHCOL
# 1    2  EDMUND HILLARY  NEW ZEALAND   29      5  1953  SOUTHCOL
# 2    3   ERNST SCHMIED  SWITZERLAND   23      5  1956  SOUTHCOL
# 3    4   JUERGE MARMET  SWITZERLAND   23      5  1956  SOUTHCOL
# 4    5     ADOLF REIST  SWITZERLAND   24      5  1956  SOUTHCOL
#
#          NAME OF THE TEAM          LEADER
# 0      BRITISH EXPEDITION  Lord John Hunt
# 1      BRITISH EXPEDITION               "
# 2  SWITZERLAND EXPEDITION    Alber Eggler
# 3  SWITZERLAND EXPEDITION               "
# 4  SWITZERLAND EXPEDITION               "

# %%
#this is suggested code

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['_id']
  ys = series['MONTH']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('_id', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('_id')
_ = plt.ylabel('MONTH')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_countries = df['COUNTRY'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.index, y=top_countries.values, palette='viridis')
plt.title('Top 10 Countries by Number of Climbers')
plt.xlabel('Country')
plt.ylabel('Number of Climbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-cab8614a1283>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.index, y=top_countries.values, palette='viridis')

# %%
route_counts = df['ROUTE'].value_counts()

plt.figure(figsize=(8, 5))
sns.barplot(x=route_counts.index, y=route_counts.values, palette='Set2')
plt.title('Climbers by Route')
plt.xlabel('Route')
plt.ylabel('Number of Climbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-2d8e672c0545>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=route_counts.index, y=route_counts.values, palette='Set2')

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['YEAR'], bins=range(df['YEAR'].min(), df['YEAR'].max() + 1, 1), color='skyblue')
plt.title('Number of Climbs Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Climbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print(df['COUNTRY'].unique())
# Out:
# ['NEPAL' 'NEW ZEALAND' 'SWITZERLAND' 'CHINA' 'USA' 'INDIA' 'JAPAN' 'ITALY'
#  'UK' 'SOUTH KOREA' 'AUSTRALIA' 'AUSTRIA' 'GERMANY' 'FRANCE' 'POLAND'
#  'YUGOSLAVIA' 'SPAIN' 'USSR' 'CANADA' 'BULGARIA' 'NETHERLANDS'
#  'CZECHOSLOVAKIA' 'NORWAY' 'MEXICO' 'SWEDEN' 'BELGIUM' 'HONG KONG'
#  'ISRAEL' 'CHILE' 'LUXEMBERG' 'PERU' 'FINLAND' 'VENEZUALA' 'ARGENTINA'
#  'TAIPEI CHINA' 'KAZAKHSTAN' 'DENMARK' 'SOUTH AFRICA' 'INDONESIA'
#  'ICELAND' 'MALAYSIA' 'IRAN' 'BOLIVIA' 'SINGAPORE' 'GEORGIA' 'ARMENIA'
#  'PAKISTAN' 'SLOVENIA' 'TURKEY' 'HUNGARY' 'SWAZILAND' 'IRELAND' 'GREECE'
#  'ECUADOR' 'BRAZIL' 'MONGOLIA' 'PHILIPPINESS' 'CANANDA' 'PHILIPPINES'
#  'TAIWAN' 'SCOTLAND' 'EGYPT' 'CZECH' 'ALGERIA' 'NO COUNTRY' 'SAUDI ARABIA'
#  'UKRAINE' 'JORDON' 'THAILAND' 'VIETNAM' 'PANAMA' 'CROATIA' 'MACEDONIA'
#  'IRISH' 'AUSTRIAN' 'ARGENTIA' 'PORTUGAL' 'COLOMBIA' 'GUATEMALA' 'OMAN'
#  'CZECH REPUBLIC' 'MALTA' 'SLOVAKIA' 'PALESTINE' 'ESTONIA'
#  'DOMINICAN REPUBLIC' 'BANGLADESH' 'BOSNIA-HERZEGOVINA' 'CYPRUS'
# ...

# %%
print(df['COUNTRY'].value_counts())
# Out:
# COUNTRY
# NEPAL        2785
# USA           624
# INDIA         312
# UK            263
# JAPAN         124
#              ...
# CYPRUS          1
# TUNISIA         1
# SRI LANKA       1
# NAMIBIA         1
# ROMANIA         1
# Name: count, Length: 101, dtype: int64

# %%
filtered_data = df[df['YEAR'] == 1953]
print(filtered_data)
# Out:
#    _id            NAME      COUNTRY  DAY  MONTH  YEAR     ROUTE  \
# 0    1  TENZING NORGAY        NEPAL   29      5  1953  SOUTHCOL
# 1    2  EDMUND HILLARY  NEW ZEALAND   29      5  1953  SOUTHCOL
#
#      NAME OF THE TEAM          LEADER
# 0  BRITISH EXPEDITION  Lord John Hunt
# 1  BRITISH EXPEDITION               "
